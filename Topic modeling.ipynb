# %%
# Import des modules généraux
import pandas as pd
import re
from collections import Counter
from dotenv import load_dotenv
import os

# Import des modules de NLP
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, OpenAI, PartOfSpeech
from bertopic.vectorizers import ClassTfidfTransformer

import spacy
from spacy.language import Language
from spacy_language_detection import LanguageDetector

from nltk.tokenize import sent_tokenize, word_tokenize
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

# Import des modules de clustering
from hdbscan import HDBSCAN
from umap import UMAP

# Import des modules de visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Import de openai pour la représentation des topics améliorée
import openai

# Chargement des variables d'environnement et initialisations
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
nlp = spacy.load("fr_core_news_md")

def get_lang_detector(nlp, name):
    return LanguageDetector(seed=42)  # We use the seed 42

Language.factory("language_detector", func=get_lang_detector)
nlp.add_pipe('language_detector', last=True)

# Texte complet contenant toutes les lettres (dans data/lettres.txt)
text  = open("data/lettres.txt", "r", encoding="utf-8").read()

# Expression régulière pour trouver les lettres
pattern = r"Lettre \d+ : \d{2}\.\d{2}\.\d{4}.*?(?=Lettre \d+ : \d{2}\.\d{2}\.\d{4}|$)"

# Trouver toutes les occurrences des lettres
letters = re.findall(pattern, text, re.DOTALL)

# Créer un DataFrame avec une ligne par lettre
df = pd.DataFrame(letters, columns=["letter"])

# Expression régulière pour trouver les dates
date_pattern = r'(\d{2}\.\d{2}\.\d{4})'

# Extraire les dates de la colonne 'letter'
df['date'] = df['letter'].str.extract(date_pattern, expand=False)

# créer une colonne year
df['year'] = df['date'].str.extract(r'(\d{4})', expand=False)

# trier par année
df = df.sort_values('year')
df
# Out:
#                                                letter        date  year
# 70  Lettre 1 : 31.03.2004\nLettre 1\n31.03.2004\n\...  31.03.2004  2004
# 67  Lettre 8 : 08.11.2004\nChers collègues, chers ...  08.11.2004  2004
# 69  Lettre 2 : 05.04.2004\nLettre 2\n05.04.2004\n\...  05.04.2004  2004
# 68  Lettre 7 : 14.09.2004\nChers collègues, chers ...  14.09.2004  2004
# 66  Lettre 9 : 24.01.2005\nChers collègues, chers ...  24.01.2005  2005
# ..                                                ...         ...   ...
# 4   Lettre 75 : 11.12.2018\n\nIntégrité académique...  11.12.2018  2018
# 3   Lettre 76 : 21.03.2019\n\nIRAFPA\tInstitut de ...  21.03.2019  2019
# 2   Lettre 77 : 27.05.2019\n\nIRAFPA\tInstitute fo...  27.05.2019  2019
# 1   Lettre 78 : 24.10.2019\n\n\n\nIRAFPA\t Institu...  24.10.2019  2019
# 0   Lettre 79 : 14.01.2020\n\n\n\n \n\nIRAFPA\tIns...  14.01.2020  2020
#
# [71 rows x 3 columns]

# %%
# Initialize an empty list to store the rows
data = []

for index, row in df.iterrows():
    date = row["date"]
    content = row["letter"]
    
    # Tokenize the content into sentences
    sentences = sent_tokenize(content)

    # Enlever les caractères spéciaux, les espaces en trop et mettre en minuscule
    #sentences = [re.sub(r"[^a-zA-Z0-9\s]", "", sentence) for sentence in sentences]
    sentences = [" ".join(sentence.split()) for sentence in sentences]
    sentences = [sentence.lower() for sentence in sentences]
    
    # Enlever les phrases qui ont moins de 16 mots
    sentences = [sentence for sentence in sentences if len(word_tokenize(sentence)) > 16]

    # Enlever les phrases en langue étrangère
    sentences = [sentence for sentence in sentences if nlp(sentence)._.language["language"] == "fr"]

    # Enlever les phrases qui ont plus de 10 caractères spéciaux
    #sentences = [sentence for sentence in sentences if len(re.findall(r"[^a-zA-Z0-9\s]", sentence)) < 10]

    # Enlever les phrases contenant "operator"
    #sentences = [sentence for sentence in sentences if "operator" not in sentence.lower()]

    # Enlever les " --" à l'intérieur des phrases
    #sentences = [sentence.replace(" --", "") for sentence in sentences]

    # Enlever les phrases en double
    sentences = list(set(sentences))
    
    # Append each sentence with its date to the list
    for sentence in sentences:
        data.append([date, sentence])

# Create a new DataFrame from the accumulated data
df_dates_sentences = pd.DataFrame(data, columns=["Date", "Sentence"])

# Supprimer les phrases en double
df_dates_sentences = df_dates_sentences.drop_duplicates(subset=["Sentence"])

df_dates_sentences
# Out:
#             Date                                           Sentence
# 0     31.03.2004  les cinq avaient emprunté plus de 95% de leur ...
# 1     31.03.2004  - deux de nos assistants doctorants ont été tr...
# 2     31.03.2004  origine grecque: deon et logos, soit le devoir...
# 3     31.03.2004  si vous connaissez des collègues qui travaille...
# 4     31.03.2004  je rêve qu'ensemble nous développions et appli...
# ...          ...                                                ...
# 1292  14.01.2020  nous avons besoin de votre contribution pour l...
# 1293  14.01.2020  les résultats de ces deux recherches seront pr...
# 1294  14.01.2020  ces recherches permettront aux dirigeants d’éc...
# 1295  14.01.2020  merci de me contacter directement par courriel...
# 1296  14.01.2020  • cycle de conférences au québec : "plagiat et...
#
# [1185 rows x 2 columns]

# %%
# Print le nombre de mots par phrase en moyenne avec l'écart-type
print(f"Moyenne: {df_dates_sentences['Sentence'].str.split().str.len().mean()}")
print(f"Ecart-type: {df_dates_sentences['Sentence'].str.split().str.len().std()}")

dates = df_dates_sentences["Date"].tolist()
sentences = df_dates_sentences["Sentence"].tolist()

# Print the length of the dates and sentences
print(f"\nNumber of dates: {len(dates)}")
print(f"Number of sentences: {len(sentences)}")
# Out:
# Moyenne: 27.369620253164555
# Ecart-type: 11.442205918942419
#
# Number of dates: 1185
# Number of sentences: 1185

# %%
# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(sentences, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/38 [00:00<?, ?it/s]

# %%
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
"""
hdbscan_model = HDBSCAN(min_cluster_size=40, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
vectorizer_model = CountVectorizer(stop_words="french", min_df=2, ngram_range=(1, 2))
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=False, bm25_weighting=False)
"""
# Out:
# '\nhdbscan_model = HDBSCAN(min_cluster_size=40, metric=\'euclidean\', cluster_selection_method=\'eom\', prediction_data=True)\nvectorizer_model = CountVectorizer(stop_words="french", min_df=2, ngram_range=(1, 2))\nctfidf_model = ClassTfidfTransformer(reduce_frequent_words=False, bm25_weighting=False)\n'

# %%
# KeyBERT
keybert_model = KeyBERTInspired()

# Part-of-Speech
pos_model = PartOfSpeech("en_core_web_sm")

# MMR
mmr_model = MaximalMarginalRelevance(diversity=0.3)

# GPT-3.5 Turbo
prompt = """
I have a topic that contains the following documents:
[DOCUMENTS]
The topic is described by the following keywords: [KEYWORDS]

En se basant sur les information ci-dessus, extrais un titre très descriptif du topic en français de maximum 7 mots. Make sure it is in the following format:
topic: <topic label>
"""

client = openai.OpenAI(api_key=openai_api_key)
openai_model = OpenAI(client,
                       model="gpt-3.5-turbo",
                       exponential_backoff=True, 
                       chat=True, 
                       nr_docs=5,
                       prompt=prompt)

# Création du modèle de topic modeling
representation_model = {
    "KeyBERT": keybert_model,
    "OpenAI": openai_model,
    "MMR": mmr_model,
    "POS": pos_model
}

# %%
topic_model = BERTopic(

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  #hdbscan_model=hdbscan_model,
  #vectorizer_model=vectorizer_model,
  representation_model=representation_model,
  #ctfidf_model=ctfidf_model,

  # Hyperparameters
  #language="french",
  #top_n_words=10,
  #min_topic_size=70,
  verbose=True
)

topics, probs = topic_model.fit_transform(sentences, embeddings)
# Out:
# 2024-03-11 16:45:38,403 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-03-11 16:45:45,575 - BERTopic - Dimensionality - Completed ✓
# 2024-03-11 16:45:45,576 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-03-11 16:45:45,610 - BERTopic - Cluster - Completed ✓
# 2024-03-11 16:45:45,615 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 7/7 [00:05<00:00,  1.28it/s]
# 2024-03-11 16:45:53,587 - BERTopic - Representation - Completed ✓

# %%
gpt_topic_labels = {topic: " | ".join(list(zip(*values))[0]) for topic, values in topic_model.topic_aspects_["OpenAI"].items()}
gpt_topic_labels[-1] = "Outlier Topic"
topic_model.set_topic_labels(gpt_topic_labels)

# %%
# Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings = UMAP(metric='cosine', random_state=42).fit_transform(embeddings)

# %%
# Visualize the documents in 2-dimensional space and show the titles on hover instead of the abstracts
fig = topic_model.visualize_documents(sentences,
                                reduced_embeddings=reduced_embeddings,
                                custom_labels=True)
fig

# %%
list_of_topics = topic_model.get_topic_info()
list_of_topics
# Out:
#    Topic  Count                                           Name  \
# 0     -1     20                         -1_de_médiation_et_des
# 1      0    966                                 0_de_et_la_des
# 2      1     71             1_chers_lettre_collègues_étudiants
# 3      2     64                              2_fraude_de_et_la
# 4      3     29  3_responsable_site_collaboratif_contributions
# 5      4     24          4_michelle_bergadaà_genève_professeur
# 6      5     11                      5_chef_rédacteur_revue_ce
#
#                                           CustomName  \
# 0                                      Outlier Topic
# 1          Plagiats et fraudes universitaires graves
# 2       Correspondance sur l'éducation universitaire
# 3            Fraude et plagiat académiques en action
# 4  Contributions régulières via site responsable ...
# 5     Michelle Bergadaà, professeur marketing Genève
# 6         Problème d'éthique dans revue scientifique
#
#                                       Representation  \
# 0  [de, médiation, et, des, notre, une, ne, adhés...
# 1      [de, et, la, des, le, les, en, un, nous, que]
# 2  [chers, lettre, collègues, étudiants, lecteurs...
# 3  [fraude, de, et, la, plagiat, le, sur, action,...
# 4  [responsable, site, collaboratif, contribution...
# 5  [michelle, bergadaà, genève, professeur, de, m...
# 6  [chef, rédacteur, revue, ce, en, de, rédacteur...
#
#                                              KeyBERT  \
# 0  [médiation, une, entre, scientifique, établiss...
# 1  [plagieur, votre, scientifique, une, plagié, ê...
# 2  [une, lecteurs, chers, pas, ceux, lettre, le, ...
# 3  [fraude, fraudes, fraudeurs, plagiat, scientif...
# 4  [responsable, responsabilité, merci, une, coll...
# 5  [marketing, communication, commun, stratégies,...
# 6  [rédacteur, rédacteurs, réfléchissent, être, p...
#
#                                               OpenAI  \
# 0         [Médiation et adhésions à une association]
# 1        [Plagiats et fraudes universitaires graves]
# 2     [Correspondance sur l'éducation universitaire]
# 3          [Fraude et plagiat académiques en action]
# 4  [Contributions régulières via site responsable...
# 5   [Michelle Bergadaà, professeur marketing Genève]
# 6       [Problème d'éthique dans revue scientifique]
#
#                                                  MMR  \
# 0  [de, médiation, et, des, notre, une, ne, adhés...
# 1      [de, et, la, des, le, les, en, un, nous, que]
# 2  [chers, lettre, collègues, étudiants, lecteurs...
# 3  [fraude, de, et, la, plagiat, le, sur, action,...
# 4  [responsable, site, collaboratif, contribution...
# 5  [michelle, bergadaà, genève, professeur, de, m...
# 6  [chef, rédacteur, revue, ce, en, de, rédacteur...
#
#                                                  POS  \
# 0  [médiation, et, des, adhésions, responsabilité...
# 1  [et, nous, que, vous, tous, si, ceux, avons, c...
# 2  [chers, lettre, collègues, étudiants, lecteurs...
# 3  [fraude, et, plagiat, action, académiques, che...
# 4  [responsable, site, contributions, vos, très, ...
# 5  [marketing, université, ovsm, et, communicatio...
# 6  [chef, excuses, dans, revues, lettre, siennes,...
#
#                                  Representative_Docs
# 0  [pour ceux qui ne l’ont pas encore fait : les ...
# 1  [• que la lecture de ce cas soit recommandée à...
# 2  [2011 chers collègues, chers étudiants, chers ...
# 3  [michelle bergadaà, mba, ph.d. présidente de l...
# 4  [un tout grand merci pour vos contributions ré...
# 5  [michelle bergadaà professeur de communication...
# 6  [l’auteur floué va demander formellement au ré...

# %% [markdown]
# # Topic modeling 2

# %%
# Ne garder que les topics -1, 0, 2, 3, 5 qui sont les plus intéressants
df_dates_sentences_2 = df_dates_sentences.copy()
df_dates_sentences_2["Topic"] = topics
df_dates_sentences_2 = df_dates_sentences_2[df_dates_sentences_2["Topic"].isin([-1, 0, 2, 3, 5])]
df_dates_sentences_2["Year"] = df_dates_sentences_2["Date"].str.extract(r'(\d{4})', expand=False)
df_dates_sentences_2
# Out:
#             Date                                           Sentence  Topic  \
# 0     31.03.2004  les cinq avaient emprunté plus de 95% de leur ...      0
# 1     31.03.2004  - deux de nos assistants doctorants ont été tr...      2
# 2     31.03.2004  origine grecque: deon et logos, soit le devoir...      0
# 3     31.03.2004  si vous connaissez des collègues qui travaille...      0
# 4     31.03.2004  je rêve qu'ensemble nous développions et appli...      0
# ...          ...                                                ...    ...
# 1292  14.01.2020  nous avons besoin de votre contribution pour l...      0
# 1293  14.01.2020  les résultats de ces deux recherches seront pr...      0
# 1294  14.01.2020  ces recherches permettront aux dirigeants d’éc...      0
# 1295  14.01.2020  merci de me contacter directement par courriel...      0
# 1296  14.01.2020  • cycle de conférences au québec : "plagiat et...      2
#
#       Year
# 0     2004
# 1     2004
# 2     2004
# 3     2004
# 4     2004
# ...    ...
# 1292  2020
# 1293  2020
# 1294  2020
# 1295  2020
# 1296  2020
#
# [1090 rows x 4 columns]

# %%
# Print la longueur des dates et des phrases
print(f"\nNumber of dates: {len(df_dates_sentences_2['Date'].tolist())}")
print(f"Number of sentences: {len(df_dates_sentences_2['Sentence'].tolist())}")

# Pré-calculer les embeddings
sentences_2 = df_dates_sentences_2["Sentence"].tolist()
dates_2 = df_dates_sentences_2["Year"].tolist()
embeddings_2 = embedding_model.encode(sentences_2, show_progress_bar=True)

topic_model_2 = BERTopic(
    
      # Pipeline models
      embedding_model=embedding_model,
      #umap_model=umap_model,
      #hdbscan_model=hdbscan_model,
      #vectorizer_model=vectorizer_model,
      representation_model=representation_model,
      #ctfidf_model=ctfidf_model,
    
      # Hyperparameters
      #language="french",
      #top_n_words=10,
      min_topic_size=5,
      verbose=True
    )

topics_2, probs_2 = topic_model_2.fit_transform(sentences_2, embeddings_2)

gpt_topic_labels_2 = {topic: " | ".join(list(zip(*values))[0]) for topic, values in topic_model_2.topic_aspects_["OpenAI"].items()}
gpt_topic_labels_2[-1] = "Outlier Topic"
topic_model_2.set_topic_labels(gpt_topic_labels_2)

# Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings_2 = UMAP(metric='cosine', random_state=42).fit_transform(embeddings_2)

# Visualize the documents in 2-dimensional space and show the titles on hover instead of the abstracts
fig = topic_model_2.visualize_documents(sentences_2,
                                reduced_embeddings=reduced_embeddings_2,
                                custom_labels=True)
fig
# Out:
# Number of dates: 1090
# Number of sentences: 1090
# Batches:   0%|          | 0/35 [00:00<?, ?it/s]
# 2024-03-11 17:04:13,348 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-03-11 17:04:16,065 - BERTopic - Dimensionality - Completed ✓
# 2024-03-11 17:04:16,066 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-03-11 17:04:16,102 - BERTopic - Cluster - Completed ✓
# 2024-03-11 17:04:16,104 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 37/37 [00:27<00:00,  1.35it/s]
# 2024-03-11 17:04:51,849 - BERTopic - Representation - Completed ✓

# %%
topic_model_2.get_topic_info()
# Out:
#     Topic  Count                                           Name  \
# 0      -1    315                                -1_de_et_des_la
# 1       0    185                             0_plagiat_de_le_du
# 2       1     64                  1_fraude_chers_plagiat_action
# 3       2     53  2_université_doctorales_universitaires_écoles
# 4       3     47             3_journal_dans_publication_article
# 5       4     35     4_responsable_site_collaboratif_régulières
# 6       5     29         5_étudiants_déontologie_professeurs_et
# 7       6     28                           6_intégrité_sa_de_et
# 8       7     22                           7_danger_que_vite_en
# 9       8     22      8_irafpa_luxembourg_institut_scientifique
# 10      9     22                      9_des_etc_communauté_mais
# 11     10     22             10_réseaux_site_analyses_diffusent
# 12     11     20         11_souhaitez_vous_courriel_désinscrire
# 13     12     18                        12_courage_avoir_bon_le
# 14     13     14                   13_tels_ai_analyse_alerteurs
# 15     14     14    14_détection_logiciels_logiciel_similarités
# 16     15     13                 15_doctorat_thèse_thèses_ayant
# 17     16     13                 16_vous_rentrée_souhaite_année
# 18     17     12            17_internet_web_prévisible_gratuits
# 19     18     11                         18_québec_canada_10_du
# 20     19     11               19_eu_instance_tribunal_exerçait
# 21     20     11             20_chef_rédacteur_revue_rédacteurs
# 22     21     11                21_notre_force_avons_situations
# 23     22     10    22_concept_document_témoignages_concurrents
# 24     23     10           23_enrichissement_unige_ch_collectif
# 25     24      9                24_humour_rubrique_joué_analysé
# 26     25      8   25_partagerons_intrigants_attendant_nouveaux
# 27     26      7                26_sites_modèle_modèles_payants
# 28     27      7       27_adhésion_adhésions_association_statut
# 29     28      6                28_avons_système_mémoires_trois
# 30     29      6       29_conseillers_plagiés_plusieurs_humeurs
# 31     30      6         30_tunisie_nos_félicitations_collègues
# 32     31      6                      31_web_diplômes_bonne_sur
# 33     32      6                   32_questions_slides_tour_vos
# 34     33      6               33_ordre_juridique_ni_académique
# 35     34      6     34_médiation_instances_spécifiques_gestion
# 36     35      5       35_dossiers_expertise_transmis_constitué
#
#                                            CustomName  \
# 0                                       Outlier Topic
# 1    Lutte contre le plagiat dans le monde académique
# 2                   Lutte contre la fraude académique
# 3   Dispositifs d'intégrité dans les écoles doctor...
# 4   Problèmes de plagiat dans la publication scien...
# 5   Reconnaissance pour contributions régulières v...
# 6         Pratiques déontologiques en milieu étudiant
# 7   Enjeux de l'intégrité dans institutions et org...
# 8            Préoccupation du danger et de la réponse
# 9                Intégrité scientifique au Luxembourg
# 10  Communication et partage d'informations dans l...
# 11           Contribution et diffusion sur notre site
# 12            Désinscription par courriel en cliquant
# 13               Le courage et les règles académiques
# 14           Analyse des lanceurs d'alerte en société
# 15    Usage des logiciels de détection de similarités
# 16      Annulation de thèse et contrôle des doctorats
# 17          Voeux chaleureux pour l'année et vacances
# 18   Plagiat sur Internet et valeurs professionnelles
# 19         Enjeux formation Québec université enquête
# 20    Licenciements par tribunaux nationaux en France
# 21      Conflit éditorial dans une revue scientifique
# 22             Cas et situations dans notre démarche.
# 23  Compétition de création de documents électroni...
# 24  Reconnaissance des contributions au projet col...
# 25    Articles scientifiques et humour dans l'édition
# 26               Cas intrigants partagés en septembre
# 27              Modèles de sites payants pour tricher
# 28  Adhésions à une association scientifique indiv...
# 29  Contrôle des mémoires universitaires datant de...
# 30            Conseillers contre le plagiat multiples
# 31  Reconnaissance aux collègues tunisiens félicit...
# 32      Utilisation du web pour vérifier les diplômes
# 33         Questions et réponses sur les diapositives
# 34  Convergence et distinction des ordres académiq...
# 35     Médiation et gestion des instances spécifiques
# 36           Gestion des dossiers d'expertise en 2016
#
#                                        Representation  \
# 0       [de, et, des, la, un, en, le, vous, les, que]
# 1    [plagiat, de, le, du, la, les, des, il, et, une]
# 2   [fraude, chers, plagiat, action, et, académiqu...
# 3   [université, doctorales, universitaires, école...
# 4   [journal, dans, publication, article, of, publ...
# 5   [responsable, site, collaboratif, régulières, ...
# 6   [étudiants, déontologie, professeurs, et, leur...
# 7   [intégrité, sa, de, et, institutions, organisa...
# 8   [danger, que, vite, en, plusieurs, très, nombr...
# 9   [irafpa, luxembourg, institut, scientifique, m...
# 10  [des, etc, communauté, mais, aussi, se, objet,...
# 11  [réseaux, site, analyses, diffusent, contribue...
# 12  [souhaitez, vous, courriel, désinscrire, si, a...
# 13  [courage, avoir, bon, le, règles, les, passez,...
# 14  [tels, ai, analyse, alerteurs, émission, lance...
# 15  [détection, logiciels, logiciel, similarités, ...
# 16  [doctorat, thèse, thèses, ayant, son, annulée,...
# 17  [vous, rentrée, souhaite, année, proches, vaca...
# 18  [internet, web, prévisible, gratuits, accrue, ...
# 19  [québec, canada, 10, du, supprime, sur, univer...
# 20  [eu, instance, tribunal, exerçait, licenciemen...
# 21  [chef, rédacteur, revue, rédacteurs, ce, excus...
# 22  [notre, force, avons, situations, comme, cas, ...
# 23  [concept, document, témoignages, concurrents, ...
# 24  [enrichissement, unige, ch, collectif, contrib...
# 25  [humour, rubrique, joué, analysé, placé, notre...
# 26  [partagerons, intrigants, attendant, nouveaux,...
# 27  [sites, modèle, modèles, payants, aidant, marc...
# 28  [adhésion, adhésions, association, statut, ind...
# 29  [avons, système, mémoires, trois, donc, ans, b...
# 30  [conseillers, plagiés, plusieurs, humeurs, mûr...
# 31  [tunisie, nos, félicitations, collègues, profe...
# 32  [web, diplômes, bonne, sur, documents, si, le,...
# 33  [questions, slides, tour, vos, répondre, répon...
# 34  [ordre, juridique, ni, académique, médiatique,...
# 35  [médiation, instances, spécifiques, gestion, p...
# 36  [dossiers, expertise, transmis, constitué, per...
#
#                                               KeyBERT  \
# 0   [une, votre, être, entre, scientifique, pas, p...
# 1   [plagieur, plagieurs, plagié, plagiats, plagia...
# 2   [fraude, fraudes, fraudeurs, plagiat, scientif...
# 3   [écoles, ecoles, universités, doctorales, univ...
# 4   [publications, éditoriale, publication, une, a...
# 5   [responsable, responsabilité, responsabilités,...
# 6   [professeurs, étudiants, étudiant, une, lettre...
# 7   [organisationnelle, organisationnelles, organi...
# 8   [une, être, plaisir, un, de, plusieurs, en, vo...
# 9   [institut, une, scientifique, scientifiques, n...
# 10  [une, intéressé, impérieux, connaissance, inte...
# 11  [collaboratif, collaboratifs, ceux, dans, merc...
# 12  [adresse, lettre, un, informellement, directem...
# 13  [courageux, votre, courage, rigoureux, sérieus...
# 14  [une, votre, calmement, alerteurs, concerne, f...
# 15  [détection, logiciels, examen, logiciel, probl...
# 16  [une, pas, doctorants, doctorante, le, histori...
# 17  [ceux, pas, voeux, quelques, bienveillance, bo...
# 18  [plagiat, fonctionnalisme, structuralisme, vot...
# 19  [études, entre, québec, connaissent, universit...
# 20  [pas, tribunal, connaissance, où, antoine, le,...
# 21  [rédacteur, rédacteurs, réfléchissent, être, p...
# 22  [scientifique, de, casuistique, des, systémiqu...
# 23  [témoignages, esthétique, automatiquement, con...
# 24  [merci, enrichissement, joyeux, le, qui, ceux,...
# 25  [humoristique, humour, classement, établisseme...
# 26  [traitement, lettre, jugement, le, pas, dans, ...
# 27  [modèles, modèle, économiques, protocole, écon...
# 28  [adhésion, adhésions, cohésion, scientifique, ...
# 29  [votre, contrôle, devoirs, pas, ou, pourquoi, ...
# 30  [une, plusieurs, choisissez, pas, leurs, fait,...
# 31  [tunisien, tunisiens, tunisie, contre, profess...
# 32  [contre, entrer, mettre, directement, des, fai...
# 33  [une, pas, dans, de, lettre, présenté, des, bi...
# 34  [ordre, ordres, être, académique, pas, juridiq...
# 35  [médiation, psychosociologie, sereinement, éta...
# 36  [dans, protocole, impacté, directement, en, et...
#
#                                                OpenAI  \
# 0               [Pandémie de plagiat dans l'académie]
# 1   [Lutte contre le plagiat dans le monde académi...
# 2                 [Lutte contre la fraude académique]
# 3   [Dispositifs d'intégrité dans les écoles docto...
# 4   [Problèmes de plagiat dans la publication scie...
# 5   [Reconnaissance pour contributions régulières ...
# 6       [Pratiques déontologiques en milieu étudiant]
# 7   [Enjeux de l'intégrité dans institutions et or...
# 8          [Préoccupation du danger et de la réponse]
# 9              [Intégrité scientifique au Luxembourg]
# 10  [Communication et partage d'informations dans ...
# 11         [Contribution et diffusion sur notre site]
# 12          [Désinscription par courriel en cliquant]
# 13             [Le courage et les règles académiques]
# 14         [Analyse des lanceurs d'alerte en société]
# 15  [Usage des logiciels de détection de similarités]
# 16    [Annulation de thèse et contrôle des doctorats]
# 17        [Voeux chaleureux pour l'année et vacances]
# 18  [Plagiat sur Internet et valeurs professionnel...
# 19       [Enjeux formation Québec université enquête]
# 20  [Licenciements par tribunaux nationaux en France]
# 21    [Conflit éditorial dans une revue scientifique]
# 22           [Cas et situations dans notre démarche.]
# 23  [Compétition de création de documents électron...
# 24  [Reconnaissance des contributions au projet co...
# 25  [Articles scientifiques et humour dans l'édition]
# 26             [Cas intrigants partagés en septembre]
# 27            [Modèles de sites payants pour tricher]
# 28  [Adhésions à une association scientifique indi...
# 29  [Contrôle des mémoires universitaires datant d...
# 30          [Conseillers contre le plagiat multiples]
# 31  [Reconnaissance aux collègues tunisiens félici...
# 32    [Utilisation du web pour vérifier les diplômes]
# 33       [Questions et réponses sur les diapositives]
# 34  [Convergence et distinction des ordres académi...
# 35   [Médiation et gestion des instances spécifiques]
# 36         [Gestion des dossiers d'expertise en 2016]
#
#                                                   MMR  \
# 0       [de, et, des, la, un, en, le, vous, les, que]
# 1    [plagiat, de, le, du, la, les, des, il, et, une]
# 2   [fraude, chers, plagiat, action, et, académiqu...
# 3   [université, doctorales, universitaires, école...
# 4   [journal, dans, publication, article, of, publ...
# 5   [responsable, site, collaboratif, régulières, ...
# 6   [étudiants, déontologie, professeurs, et, leur...
# 7   [intégrité, sa, de, et, institutions, organisa...
# 8   [danger, que, vite, en, plusieurs, très, nombr...
# 9   [irafpa, luxembourg, institut, scientifique, m...
# 10  [des, etc, communauté, mais, aussi, se, objet,...
# 11  [réseaux, site, analyses, diffusent, contribue...
# 12  [souhaitez, vous, courriel, désinscrire, si, a...
# 13  [courage, avoir, bon, le, règles, les, passez,...
# 14  [tels, ai, analyse, alerteurs, émission, lance...
# 15  [détection, logiciels, logiciel, similarités, ...
# 16  [doctorat, thèse, thèses, ayant, son, annulée,...
# 17  [vous, rentrée, souhaite, année, proches, vaca...
# 18  [internet, web, prévisible, gratuits, accrue, ...
# 19  [québec, canada, 10, du, supprime, sur, univer...
# 20  [eu, instance, tribunal, exerçait, licenciemen...
# 21  [chef, rédacteur, revue, rédacteurs, ce, excus...
# 22  [notre, force, avons, situations, comme, cas, ...
# 23  [concept, document, témoignages, concurrents, ...
# 24  [enrichissement, unige, ch, collectif, contrib...
# 25  [humour, rubrique, joué, analysé, placé, notre...
# 26  [partagerons, intrigants, attendant, nouveaux,...
# 27  [sites, modèle, modèles, payants, aidant, marc...
# 28  [adhésion, adhésions, association, statut, ind...
# 29  [avons, système, mémoires, trois, donc, ans, b...
# 30  [conseillers, plagiés, plusieurs, humeurs, mûr...
# 31  [tunisie, nos, félicitations, collègues, profe...
# 32  [web, diplômes, bonne, sur, documents, si, le,...
# 33  [questions, slides, tour, vos, répondre, répon...
# 34  [ordre, juridique, ni, académique, médiatique,...
# 35  [médiation, instances, spécifiques, gestion, p...
# 36  [dossiers, expertise, transmis, constitué, per...
#
#                                                   POS  \
# 0   [vous, nous, ou, faire, lettre, ceux, tous, in...
# 1   [de, et, nous, étudiants, vous, académique, le...
# 2   [fraude, chers, plagiat, action, et, académiqu...
# 3   [universitaires, écoles, et, nous, les, présid...
# 4   [journal, article, deux, articles, auteurs, pu...
# 5   [responsable, site, contributions, vos, votre,...
# 6   [étudiants, déontologie, professeurs, et, leur...
# 7   [et, institutions, organisations, les, nous, f...
# 8   [danger, que, plusieurs, très, outils, ont, ac...
# 9   [irafpa, scientifique, missions, conseillers, ...
# 10  [objet, de, messages, espace, connaissance, lo...
# 11  [site, lettres, diffuser, tous, ceux, et, insc...
# 12  [souhaitez, vous, désinscrire, si, adresser, s...
# 13  [courage, passez, et, vous, certains, temps, t...
# 14  [lanceurs, alerteurs, une, nous, acteurs, pour...
# 15  [détection, logiciels, similarités, turnitin, ...
# 16  [doctorat, thèse, thèses, annulée, vérifier, p...
# 17  [vous, souhaite, proches, vacances, ceux, bell...
# 18  [internet, gratuits, risqué, révolution, dispo...
# 19  [sur, de, les, nos, la, linguistes, globalemen...
# 20  [instance, licenciement, national, procédé, fo...
# 21  [chef, revue, excuses, revues, auteur, co, dan...
# 22  [force, avons, situations, gènes, posture, cai...
# 23  [concept, document, témoignages, concurrents, ...
# 24       [collectif, conclure, dernier, , , , , , , ]
# 25  [humour, avions, dirigeants, nous, également, ...
# 26  [partagerons, intrigants, vacances, belles, no...
# 27  [sites, modèle, modèles, tricher, payants, cli...
# 28  [adhésion, adhésions, individuelles, moment, i...
# 29  [avons, système, mémoires, méditer, datant, pr...
# 30  [conseillers, plagiés, plusieurs, mûrs, humeur...
# 31  [tunisie, nos, félicitations, collègues, profe...
# 32  [diplômes, documents, si, net, adversaire, ins...
# 33  [questions, slides, tour, réponses, même, posé...
# 34  [académique, cessons, pardonnons, arguant, con...
# 35  [médiation, instances, spécifiques, gestion, o...
# 36  [dossiers, instruits, personnalités, impacté, ...
#
#                                   Representative_Docs
# 0   [un jeu qui vous permet de vous mettre dans la...
# 1   [• enfin, pour tous ceux qui ne savent comment...
# 2   [• l' institut international de recherche et d...
# 3   [face à cette demande, l’irafpa organise son a...
# 4   [le chercheur dont nous racontions la mésavent...
# 5   [un tout grand merci pour vos contributions ré...
# 6   [- enfin, pour tous ceux qui m’écrivent leur d...
# 7   [• certes, c’est au niveau global, structurel ...
# 8   [aussi, vos besoins étant souvent similaires, ...
# 9   [au nom de tous les membres actifs de l’instit...
# 10  [mais il a aussi intéressé de nombreux collègu...
# 11  [merci à tous ceux qui contribuent directement...
# 12  [si vous souhaitez vous désinscrire de cette l...
# 13  [merci d’avoir compris que le courage, ce n’es...
# 14  [précisons que l’anonymat de tels « lanceurs d...
# 15  [alors, ils estimeront caducs les discours off...
# 16  [4/ les actes des délinquants du savoir commen...
# 17  [a toutes et tous, je souhaite de très belles ...
# 18  [• que la lecture de ce cas soit recommandée à...
# 19  [du québec : je suis revenue enchantée de l’ex...
# 20  [dès que l’institution où il exerçait a eu con...
# 21  [l’auteur floué va demander formellement au ré...
# 22  [il me semble vain de ne considérer que la sau...
# 23  [3- les concurrents doivent, dans un bref laps...
# 24  [encore un tout grand merci à ceux qui contrib...
# 25  [conflits d’intérêts dans l’édition d’articles...
# 26  [en attendant les nouveaux cas fort intrigants...
# 27  [ces deux modèles se sont dotés de codes d’« é...
# 28  [créez une association scientifique, faites pa...
# 29  [pourquoi ne pas imaginer d'abandonner simplem...
# 30  [les conseillers : nous sommes aussi plusieurs...
# 31  [mais nos collègues du liban, de tunisie et d’...
# 32  [c’est si facile de fabriquer des diplômes ave...
# 33  [a mon tour : comme cadeau de saison, j’aimera...
# 34  [car - nous ne cessons de l’exprimer - l'ordre...
# 35  [et cela vous demande du travail et de la pati...
# 36  [le socle d’expertise est constitué de huit do...

# %% [markdown]
# # Sélection des topics pertinents

# %%
# Visualize the documents in 2-dimensional space and show the titles on hover instead of the abstracts
fig = topic_model_2.visualize_documents(sentences_2,
                                reduced_embeddings=reduced_embeddings_2,
                                custom_labels=True,
                                # Tous les topics sauf 4, 7 et 17
                                topics=[topic if topic not in [-1, 11, 16] else None for topic in topics_2])
fig

# %%
fig.write_html("output/visualize_documents_all.html")

# %% [markdown]
# DTM

# %%
# La ligne suivante permet de lancer le DTM (Dynamic Topic Modeling) sur les données
topics_over_time = topic_model_2.topics_over_time(sentences_2, dates_2, evolution_tuning=True)
# Out:
# 16it [00:00, 43.61it/s]

# %%
# Comme il s'agit d'un plotly, nous pouvons également tracer les étiquettes des sujets.
fig_dtm = topic_model_2.visualize_topics_over_time(topics_over_time, custom_labels=True, normalize_frequency=False, topics=[topic if topic not in [-1, 11, 16] else None for topic in topics_2])
fig_dtm.write_html("output/visualize_topics_over_time.html")
fig_dtm
